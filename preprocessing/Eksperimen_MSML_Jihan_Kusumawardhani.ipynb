# %% [markdown]
# > # **PROYEK AKHIR MSML**
#
# NAMA : JIHAN KUSUMAWARDHANI
#
# ---
#
# USERNAME DICODING : WWADRN
#
# ---
#
# KELAS : MEMBANGUN SISTEM MACHINE LEARNING
#
# ---

# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Dataset ini menyajikan informasi biaya asuransi medis yang ditagihkan kepada 1338 individu. Data ini sangat berharga dan sering digunakan dalam bidang ekonomi kesehatan, aktuaria (perhitungan premi asuransi), dan pembelajaran mesin karena variabel-variabelnya mencakup gabungan faktor demografi dan kesehatan yang secara langsung memengaruhi penetapan harga asuransi. Variabel target utama dari kumpulan data ini adalah charges (biaya), yang merepresentasikan total biaya asuransi medis yang ditagihkan kepada individu.
#
# ---
#
# >## Detail Struktur Data
#
# Kumpulan data ini didasarkan pada populasi individu yang diasuransikan, mencakup enam variabel prediktor kunci:
#
# | Kolom | Tipe Data | Deskripsi dan Relevansi Klinis/Ekonomi |
# | :--- | :--- | :--- |
# | **`age`** | *Integer* | Usia penerima manfaat utama. Usia adalah prediktor biaya kesehatan yang sangat kuat karena risiko penyakit kronis meningkat seiring bertambahnya usia. |
# | **`sex`** | *Kategorikal* | Jenis kelamin penerima manfaat (laki-laki, perempuan). Variabel ini dapat mengungkapkan perbedaan biaya medis antara kedua jenis kelamin. |
# | **`bmi`** | *Float* | **Indeks Massa Tubuh** (*Body Mass Index*), merupakan ukuran lemak tubuh berdasarkan tinggi dan berat badan. BMI tinggi sering kali menjadi indikator risiko penyakit terkait gaya hidup dan obesitas. |
# | **`children** | *Integer* | Jumlah anak/tanggungan yang dicakup oleh asuransi kesehatan individu. Ini dapat memengaruhi struktur premi atau biaya klaim. |
# | **`smoker`** | *Kategorikal* | Status merokok penerima manfaat (ya, tidak). Ini adalah salah satu faktor risiko gaya hidup paling signifikan yang memengaruhi biaya asuransi. |
# | **`region`** | *Kategorikal* | Wilayah tempat tinggal di AS (Timur Laut, Barat Laut, Tenggara, Barat Daya). Biaya medis dan penetapan harga asuransi sering bervariasi secara geografis. |
# | **`charges`** | *Float* | **Biaya Asuransi Medis** yang ditagihkan kepada penerima manfaat. Ini adalah variabel target yang harus diprediksi. |
#
# ---
#
# >## Kegunaan dan Aplikasi Utama
#
# *Dataset* ini umumnya digunakan untuk tujuan berikut:
#
# 1.  **Pemodelan Regresi dan Prediksi Biaya (*Predictive Modeling*):**
#     * Membangun model regresi (misalnya Regresi Linear atau model yang lebih kompleks) untuk memprediksi biaya asuransi (`charges`) berdasarkan variabel demografi dan kesehatan.
#     * Tujuan utamanya adalah mengidentifikasi formula matematis yang dapat digunakan perusahaan asuransi untuk menetapkan premi secara akurat dan adil.
#
# 2.  **Riset Ekonomi Kesehatan:**
#     * Menganalisis elastisitas biaya: Seberapa besar kenaikan biaya asuransi sebagai respons terhadap perubahan dalam variabel risiko (misalnya, peningkatan satu unit BMI, atau menjadi perokok).
#     * Mengeksplorasi tren keterjangkauan layanan kesehatan (**Affordability**) berdasarkan demografi dan wilayah.
#
# 3.  **Analisis Aktuaria dan Penetapan Harga Asuransi:**
#     * Memahami kontribusi marginal dari setiap faktor risiko terhadap biaya asuransi. Misalnya, mengukur dampak finansial spesifik dari status merokok terhadap total biaya yang ditanggung asuransi.
#
# 4.  **Edukasi dan Tutorial Pembelajaran Mesin:**
#     * Berfungsi sebagai *dataset* klasik yang ideal untuk mengajarkan konsep regresi, rekayasa fitur (*feature engineering*), dan interpretasi model.
#
# ---
#
#
# >## Potensi Analisis Mendalam dan Pandangan ke Depan
#
#
# Jika Anda ingin menganalisis lebih jauh, fokuslah pada area-area berikut:
#
# ### A. Interaksi Faktor Risiko
#
# * **Interaksi Perokok dan BMI:** Periksa apakah gabungan dari **merokok dan BMI tinggi** menghasilkan biaya asuransi yang jauh lebih tinggi (efek sinergis) dibandingkan jika kedua faktor tersebut dinilai sendiri-sendiri.
# * **Interaksi Usia dan Kondisi:** Analisis bagaimana usia berinteraksi dengan penyakit terkait gaya hidup (BMI, merokok) dalam mendorong biaya.
#
# ### B. Analisis Geografis
#
# * **Analisis Regional:** Identifikasi wilayah mana (northeast, southeast, dll.) yang memiliki biaya asuransi rata-rata tertinggi. Cari tahu apakah faktor-faktor risiko tertentu (misalnya tingkat merokok) lebih umum di wilayah berbiaya tinggi.
#
# ### C. Segmentasi Pelanggan
#
# * Gunakan teknik klastering untuk mengelompokkan individu ke dalam "Kelompok Risiko Biaya" (misalnya, kelompok risiko rendah, sedang, dan tinggi) berdasarkan kombinasi usia, BMI, dan status merokok, lalu bandingkan biaya rata-rata di setiap kelompok.

# %% [markdown]
# # **2. Import Library**

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %% [markdown]
# # **3. Memuat Dataset**

# %%
import pandas as pd
# Load dataset
data = pd.read_csv("/content/insurance.csv")

# %%
# Menampilkan 5 baris pertama dataset
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Menampilkan 5 baris terakhir dataset
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**

# %%
print(data.isnull().sum())
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 1

# %%
for col in data.select_dtypes(include=['object']).columns:
    print(data[col].value_counts(), "\n")
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
#
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
print("\nRata-rata Charges berdasarkan Status Perokok ")
print(data.groupby("smoker")["charges"].mean())

print("\nRata-rata Charges berdasarkan Wilayah ")
print(data.groupby("region")["charges"].mean())

print("\nRata-rata Charges berdasarkan Jumlah Anak ")
print(data.groupby("children")["charges"].mean())
# Out:
# Rata-rata Charges berdasarkan Status Perokok
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64
#
# Rata-rata Charges berdasarkan Wilayah
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64
#
# Rata-rata Charges berdasarkan Jumlah Anak
# children
# 0    12365.975602
# 1    12731.171832
# 2    15073.563734
# 3    15355.318367
# 4    13850.656311
# 5     8786.035247
# Name: charges, dtype: float64

# %% [markdown]
# # **5. Data Preprocessing**

# %%
# Membuat salinan DataFrame
df = data.copy()

# %%
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
df = df.dropna()

# %%
# 2. Menghapus Data Duplikat
df = df.drop_duplicates()

# %%
from sklearn.preprocessing import MinMaxScaler
# 3. Normalisasi atau Standarisasi Fitur
categirical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['number']).columns
target_col = 'charges'

numerical_cols = numerical_cols.drop(target_col)

scaler = MinMaxScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
# 4. Deteksi dan Penanganan Outlier
for feature in numerical_cols:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]

# %%
# 5. Encoding Data Kategorikal
df = pd.get_dummies(df, columns=categirical_cols,dtype=int)
